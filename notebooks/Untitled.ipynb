# %%
import pandas as pd

# %%
import numpy as np

# %%
bitcoincash= pd.read_csv('../data/raw/cryptocurrencypricehistory/bitcoin_cash_price.csv')

# %%
ethereum= pd.read_csv('../data/raw/cryptocurrencypricehistory/ethereum_price.csv')

# %%
omisego= pd.read_csv('../data/raw/cryptocurrencypricehistory/omisego_price.csv')

# %%
iota= pd.read_csv('../data/raw/cryptocurrencypricehistory/iota_price.csv')

# %%
qtum= pd.read_csv('../data/raw/cryptocurrencypricehistory/qtum_price.csv')

# %%
bitcoin= pd.read_csv('../data/raw/cryptocurrencypricehistory/bitcoin_price.csv')

# %%
litecoin= pd.read_csv('../data/raw/cryptocurrencypricehistory/litecoin_price.csv')

# %%
ripple= pd.read_csv('../data/raw/cryptocurrencypricehistory/ripple_price.csv')

# %%
bitconnect= pd.read_csv('../data/raw/cryptocurrencypricehistory/bitconnect_price.csv')

# %%
monero=pd.read_csv('../data/raw/cryptocurrencypricehistory/monero_price.csv')

# %%
stratis=pd.read_csv('../data/raw/cryptocurrencypricehistory/stratis_price.csv')

# %%
dash=pd.read_csv('../data/raw/cryptocurrencypricehistory/dash_price.csv')

# %%
nem=pd.read_csv('../data/raw/cryptocurrencypricehistory/nem_price.csv')

# %%
waves=pd.read_csv('../data/raw/cryptocurrencypricehistory/waves_price.csv')

# %%
ethereumclassic=pd.read_csv('../data/raw/cryptocurrencypricehistory/ethereum_classic_price.csv')

# %%
neo=pd.read_csv('../data/raw/cryptocurrencypricehistory/neo_price.csv')

# %%
numeraire=pd.read_csv('../data/raw/cryptocurrencypricehistory/numeraire_price.csv')

# %%
bitcoin.head()
# Out:
#            Date     Open     High      Low    Close      Volume   Market Cap
# 0  Sep 05, 2017  4228.29  4427.84  3998.11  4376.53  2697970000  69954400000
# 1  Sep 04, 2017  4591.63  4591.63  4108.40  4236.31  2987330000  75955500000
# 2  Sep 03, 2017  4585.27  4714.08  4417.59  4582.96  1933190000  75841700000
# 3  Sep 02, 2017  4901.42  4975.04  4469.24  4578.77  2722140000  81060600000
# 4  Sep 01, 2017  4701.76  4892.01  4678.53  4892.01  2599080000  77748400000

# %%
ethereum.head()
# Out:
#            Date    Open    High     Low   Close         Volume      Market Cap
# 0  Sep 05, 2017  297.57  318.57  268.29  312.99  1,551,050,000  28,100,000,000
# 1  Sep 04, 2017  347.13  347.13  279.94  295.17  1,801,690,000  32,774,000,000
# 2  Sep 03, 2017  350.23  366.49  332.23  347.48    986,266,000  33,059,800,000
# 3  Sep 02, 2017  387.82  389.35  328.10  348.98  1,483,600,000  36,601,200,000
# 4  Sep 01, 2017  383.47  390.04  383.47  387.74    874,222,000  36,182,900,000

# %%
dash.head()
# Out:
#            Date    Open    High     Low   Close      Volume     Market Cap
# 0  Sep 05, 2017  316.88  333.83  286.53  327.23  53,928,800  2,388,710,000
# 1  Sep 04, 2017  356.94  357.21  301.84  316.13  44,170,200  2,689,920,000
# 2  Sep 03, 2017  354.63  373.08  338.23  356.39  34,945,200  2,670,270,000
# 3  Sep 02, 2017  393.53  395.92  329.27  350.17  54,813,400  2,962,400,000
# 4  Sep 01, 2017  377.92  393.35  376.34  393.35  55,440,700  2,844,110,000

# %%
bitcoin.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
monero.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
nem.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
ethereum.count()
# Out:
# Date          761
# Open          761
# High          761
# Low           761
# Close         761
# Volume        761
# Market Cap    761
# dtype: int64

# %%
bitcoin.count()
# Out:
# Date          1592
# Open          1592
# High          1592
# Low           1592
# Close         1592
# Volume        1592
# Market Cap    1592
# dtype: int64

# %%
nem.count()
# Out:
# Date          889
# Open          889
# High          889
# Low           889
# Close         889
# Volume        889
# Market Cap    889
# dtype: int64

# %%
bitcoin.describe()
# Out:
#               Open         High          Low        Close    Market Cap
# count  1592.000000  1592.000000  1592.000000  1592.000000  1.592000e+03
# mean    658.283649   676.271727   641.050616   660.837795  9.964862e+09
# std     723.653014   749.473657   699.635365   729.447612  1.209521e+10
# min      68.500000    74.560000    65.530000    68.430000  7.792550e+08
# 25%     258.350000   263.930000   253.177500   258.592500  3.648115e+09
# 50%     444.885000   450.605000   437.180000   444.705000  6.449795e+09
# 75%     680.187500   703.960000   660.775000   682.142500  1.021785e+10
# max    4901.420000  4975.040000  4678.530000  4892.010000  8.106060e+10

# %%
ethereum.describe()
# Out:
#              Open        High         Low       Close
# count  761.000000  761.000000  761.000000  761.000000
# mean    49.895319   52.372998   47.483389   50.287726
# std     94.701419   99.021937   90.028103   95.157500
# min      0.431589    0.482988    0.420897    0.434829
# 25%      4.360000    4.770000    4.030000    4.400000
# 50%     11.110000   11.340000   10.750000   11.080000
# 75%     17.360000   18.880000   16.370000   17.600000
# max    397.590000  414.760000  383.470000  401.490000

# %%
iota.describe()
# Out:
#             Open       High        Low      Close
# count  85.000000  85.000000  85.000000  85.000000
# mean    0.501695   0.537700   0.455827   0.502194
# std     0.254753   0.267625   0.232656   0.256240
# min     0.157961   0.176099   0.147933   0.158688
# 25%     0.286164   0.304476   0.262736   0.284565
# 50%     0.413371   0.437340   0.388231   0.410757
# 75%     0.722169   0.775863   0.658006   0.721535
# max     1.040000   1.100000   0.998241   1.050000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
ethereum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        761 non-null    object
#  1   Open        761 non-null    float64
#  2   High        761 non-null    float64
#  3   Low         761 non-null    float64
#  4   Close       761 non-null    float64
#  5   Volume      761 non-null    object
#  6   Market Cap  761 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 41.7+ KB

# %%
nem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        889 non-null    object
#  1   Open        889 non-null    float64
#  2   High        889 non-null    float64
#  3   Low         889 non-null    float64
#  4   Close       889 non-null    float64
#  5   Volume      889 non-null    object
#  6   Market Cap  889 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 48.7+ KB

# %%
qtum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        30 non-null     object
#  1   Open        30 non-null     float64
#  2   High        30 non-null     float64
#  3   Low         30 non-null     float64
#  4   Close       30 non-null     float64
#  5   Volume      30 non-null     object
#  6   Market Cap  30 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 1.8+ KB

# %%
bitcoin['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
ethereum['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
bitcoin.boxplot(column='Close',by='Date')
# Out:
# <AxesSubplot:title={'center':'Close'}, xlabel='Date'>

# %%
 bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
nem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        889 non-null    object
#  1   Open        889 non-null    float64
#  2   High        889 non-null    float64
#  3   Low         889 non-null    float64
#  4   Close       889 non-null    float64
#  5   Volume      889 non-null    object
#  6   Market Cap  889 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 48.7+ KB

# %%
neo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        362 non-null    object
#  1   Open        362 non-null    float64
#  2   High        362 non-null    float64
#  3   Low         362 non-null    float64
#  4   Close       362 non-null    float64
#  5   Volume      362 non-null    object
#  6   Market Cap  362 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 19.9+ KB

# %%
from pandas_profiling import ProfileReport

# %%
report=ProfileReport(bitcoin,title="bitcoin")

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-04-23 22:31:38.102820&quot;&gt;&lt;title&gt;bitcoin&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
ethereum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        761 non-null    object
#  1   Open        761 non-null    float64
#  2   High        761 non-null    float64
#  3   Low         761 non-null    float64
#  4   Close       761 non-null    float64
#  5   Volume      761 non-null    object
#  6   Market Cap  761 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 41.7+ KB

# %%
bitcoincash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        45 non-null     object
#  1   Open        45 non-null     float64
#  2   High        45 non-null     float64
#  3   Low         45 non-null     float64
#  4   Close       45 non-null     float64
#  5   Volume      45 non-null     object
#  6   Market Cap  45 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 2.6+ KB

# %%
qtum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        30 non-null     object
#  1   Open        30 non-null     float64
#  2   High        30 non-null     float64
#  3   Low         30 non-null     float64
#  4   Close       30 non-null     float64
#  5   Volume      30 non-null     object
#  6   Market Cap  30 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 1.8+ KB

# %%
litecoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 87.2+ KB

# %%
monero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1203 non-null   object
#  1   Open        1203 non-null   float64
#  2   High        1203 non-null   float64
#  3   Low         1203 non-null   float64
#  4   Close       1203 non-null   float64
#  5   Volume      1203 non-null   int64
#  6   Market Cap  1203 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 65.9+ KB

# %%
numeraire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        30 non-null     object
#  1   Open        30 non-null     float64
#  2   High        30 non-null     float64
#  3   Low         30 non-null     float64
#  4   Close       30 non-null     float64
#  5   Volume      30 non-null     object
#  6   Market Cap  30 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 1.8+ KB

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 87.2+ KB

# %%
bitcoin['Market Cap']=bitcoin['Market Cap'].astype(object)

# %%
monero['Market Cap']=monero['Market Cap'].astype(object)

# %%
monero['Volume']=monero['Volume'].astype(object)

# %%
monero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1203 entries, 0 to 1202
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1203 non-null   object
#  1   Open        1203 non-null   float64
#  2   High        1203 non-null   float64
#  3   Low         1203 non-null   float64
#  4   Close       1203 non-null   float64
#  5   Volume      1203 non-null   object
#  6   Market Cap  1203 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 65.9+ KB

# %%
litecoin['Market Cap']=litecoin['Market Cap'].astype(object)

# %%
litecoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1592 non-null   object
#  1   Open        1592 non-null   float64
#  2   High        1592 non-null   float64
#  3   Low         1592 non-null   float64
#  4   Close       1592 non-null   float64
#  5   Volume      1592 non-null   object
#  6   Market Cap  1592 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 87.2+ KB

# %%
bigdf=pd.merge(bitcoin,ethereum, on='Date',how='outer',suffixes=('_bitcoin','_ethereum'))

# %%
bigdf.head()
# Out:
#            Date  Open_bitcoin  High_bitcoin  Low_bitcoin  Close_bitcoin  \
# 0  Sep 05, 2017       4228.29       4427.84      3998.11        4376.53
# 1  Sep 04, 2017       4591.63       4591.63      4108.40        4236.31
# 2  Sep 03, 2017       4585.27       4714.08      4417.59        4582.96
# 3  Sep 02, 2017       4901.42       4975.04      4469.24        4578.77
# 4  Sep 01, 2017       4701.76       4892.01      4678.53        4892.01
#
#   Volume_bitcoin Market Cap_bitcoin  Open_ethereum  High_ethereum  \
# 0     2697970000        69954400000         297.57         318.57
# 1     2987330000        75955500000         347.13         347.13
# 2     1933190000        75841700000         350.23         366.49
# 3     2722140000        81060600000         387.82         389.35
# 4     2599080000        77748400000         383.47         390.04
#
#    Low_ethereum  Close_ethereum Volume_ethereum Market Cap_ethereum
# ...

# %%
bigdf2=pd.merge(dash,litecoin, on='Date',how='outer',suffixes=('_dash','_litecoin'))

# %%
bigdf2.head()
# Out:
#            Date  Open_dash  High_dash  Low_dash  Close_dash Volume_dash  \
# 0  Sep 05, 2017     316.88     333.83    286.53      327.23  53,928,800
# 1  Sep 04, 2017     356.94     357.21    301.84      316.13  44,170,200
# 2  Sep 03, 2017     354.63     373.08    338.23      356.39  34,945,200
# 3  Sep 02, 2017     393.53     395.92    329.27      350.17  54,813,400
# 4  Sep 01, 2017     377.92     393.35    376.34      393.35  55,440,700
#
#   Market Cap_dash  Open_litecoin  High_litecoin  Low_litecoin  Close_litecoin  \
# 0   2,388,710,000          65.25          72.44         59.05           71.29
# 1   2,689,920,000          76.73          76.73         61.24           65.21
# 2   2,670,270,000          78.98          82.83         73.61           76.84
# 3   2,962,400,000          85.83          92.07         72.23           79.02
# 4   2,844,110,000          70.86          87.41         70.01           86.04
#
#   Volume_litecoin Market Cap_litecoin
# ...

# %%
bigdfTripple=pd.merge(bigdf,bigdf2, on='Date',how='outer')

# %%
bigdfTripple.head()
# Out:
#            Date  Open_bitcoin  High_bitcoin  Low_bitcoin  Close_bitcoin  \
# 0  Sep 05, 2017       4228.29       4427.84      3998.11        4376.53
# 1  Sep 04, 2017       4591.63       4591.63      4108.40        4236.31
# 2  Sep 03, 2017       4585.27       4714.08      4417.59        4582.96
# 3  Sep 02, 2017       4901.42       4975.04      4469.24        4578.77
# 4  Sep 01, 2017       4701.76       4892.01      4678.53        4892.01
#
#   Volume_bitcoin Market Cap_bitcoin  Open_ethereum  High_ethereum  \
# 0     2697970000        69954400000         297.57         318.57
# 1     2987330000        75955500000         347.13         347.13
# 2     1933190000        75841700000         350.23         366.49
# 3     2722140000        81060600000         387.82         389.35
# 4     2599080000        77748400000         383.47         390.04
#
#    Low_ethereum  ...  Low_dash Close_dash Volume_dash  Market Cap_dash  \
# ...

# %%
clbigdf=ProfileReport(bigdfTripple,title="bigdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d1c37619b78c> in <module>
# ----> 1 clbigdf=ProfileReport(bigdfTripple,title="bigdf")
#
# NameError: name 'ProfileReport' is not defined

# %%
bigdfreport
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2033195b54cd> in <module>
# ----> 1 bigdfreport
#
# NameError: name 'bigdfreport' is not defined
